# %%
import numpy as np
import pandas as pd

from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df=pd.read_csv("software reviews.csv")
print(df.isnull().sum())
df.head()
# Out:
# userName         524
# review_title    5525
# content            0
# appId              0
# dtype: int64
#                   userName review_title  \
# 0  Ratneshwar Prasad Sinha          NaN
# 1               Arun Kumar          NaN
# 2              Alex Mendez          NaN
# 3           Weeping Willow          NaN
# 4              Phree Zleva          NaN
#
#                                              content appId
# 0                                    Upgrade the app  zoom
# 1       Notification sound not working in samsung s4  zoom
# 2   i dunno why do i always error 103 when i sign in  zoom
# 3                                   It will not open  zoom
# 4  Wants access to everything. Talk about spy web...  zoom

# %%
features=df.iloc[:,2].values

# %%
processed_features = []

for sentence in range(0, len(features)):
    # Remove all the special characters
    processed_feature = re.sub(r'\W', ' ', str(features[sentence]))

    # remove all single characters
    processed_feature= re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_feature)

    # Remove single characters from the start
    processed_feature = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_feature) 

    # Substituting multiple spaces with single space
    processed_feature = re.sub(r'\s+', ' ', processed_feature, flags=re.I)

    # Removing prefixed 'b'
    processed_feature = re.sub(r'^b\s+', '', processed_feature)

    # Converting to Lowercase
    processed_feature = processed_feature.lower()

    processed_features.append(processed_feature)

# %%
processed_features
# Out:
# ['upgrade the app',
#  'notification sound not working in samsung s4',
#  'i dunno why do always error 103 when sign in',
#  'it will not open',
#  'wants access to everything talk about spy webb surely that is not needed if you should only have call',
#  'audio didn work',
#  'download is pending for more than 1 hour ',
#  'great',
#  'i have not been able to successfully use the app ',
#  'can make video conference from polycom to zoom ',
#  'can hear anything',
#  'it won download',
#  'i just tried and it failed to send verification the message was partial',
#  'hello please improve one thing keep all meeting idz save once they enterd in meeting please do desktop update for that as well ',
#  'unable to understand that what is this ',
#  'worst video quality',
#  'where is link is slow then what we can do ',
#  'watching large call on mobile everyone that joins flashes an alert in the middle of the screen ',
#  'i cant here anything',
#  'after installing and joining meeting my screen started flashing off and on even outside of the app had to slowly work my way towards the task manager to force quit as my screen kept turning off the moment killed the app everything started working again and immediately uninstalled have no idea how that got so messed up but considering the ridiculous level of permissions it wanted it could be million different things samsung galaxy note 2 on verizon devs ',
#  'bokvash',
#  'terrible audio on good connection terrible ui ',
#  'won even install ',
#  'aw3some',
#  'no',
#  'very disappointing app features are good but phone gets hanged every time',
#  'won open on my s5 active',
#  'i couldn login with my sso takes me to webpage where m already signed in when click sign in m already signed in on the webview ',
#  'nice utility',
#  'haven used the app uninstalled it right after it was installed my complaint is that the app requires permissions to every bit of information contacts files etc on your phone nothing is confidential from zoom not your information data or even your phone device settings which zoom requires permission to change wouldn trust this app on any device with any confidential information whatsoever ',
#  'hardly worked waste of time',
#  'couldnt connect to my mtg',
#  'can some one solve my problem my connection to zoom is blocked by firewall or proxy',
#  '2d',
#  'sound does not work so have to read the lips ',
#  'i cant get sound restarted phone uninstalled app and reinstalled still no sound ',
#  'every time try to do video chat it says error 5 ',
#  'your speed is too low',
#  'it so annoying can seems to download it',
#  'audio would not work no contol panel will not even try ro use this again',
#  'i guess it works for some and not for others can download it but can open the app restarted my phone but still nothing it just won open tried to download it in my tablet and it won even download tweet all my other apps are working weird sad moving on',
#  'unable to download app',
#  'this app doesn let you go in with out email and password this is the most werst app ever',
#  'trying to join meet and keep in valid id',
#  'unable to join meeting been getting error 1132 ',
#  'works great but one big bug have my settings to join meetings with video off yet the app randomly turns the video on without my knowledge it might be when my phone loses signal and then reconnects but still huge privacy concern',
#  'poor',
#  'tried to use the app for meeting but no one could hear me nor could hear them tried rejoining the meeting couple of times and checked all permissions had been allowed in settings so missed out on an important part of my training because of this disappointing ',
#  'does not work correctly with corporate sso server unfortunately for me when try to join meeting the application logout me additionally it show me request to download an version for android but use it exactly how can it be that the application shows request to download of itself very strange ',
#  'couldn hear anything such shame was looking forward to this',
#  'i have not access it limited my phone',
#  'audio does not work for android tried their fixes online still nothing ',
#  'poor could not download video',
#  'error code 963 wont let me install',
#  'your app is not installing on my phone ',
#  'i don get it one bit',
#  'worst app ever',
#  'why no explanation for the permission for location including precise location ',
#  'nothin',
#  'garbage',
#  'it will not work for me',
#  'never works have an android s7 edge operation on android 8 0 cant even connect to simple meeting where the host has an iphone 2 thumbs down ',
#  'i really hate it my lots of time ruin in meeting but it any response and have booked for class but am not able to start online class',
#  'very bad ui they should use mac app ui',
#  'i ve unistalled and downloaded again with out sound ',
#  'signing in through facebook does not work so you will have to create an account before joining the meeting opening through browser on smartphone or tablet doesn work either it sends you to the play store ',
#  'useless on mobile too complicated ',
#  'be warned for anybody not in the us you give the app permission to use your phone and text msgs so outgoing calls and texts are made to us number you will be charged an arm and leg for long distance fees by your service provider for using this app ',
#  'horrible ',
#  'still downloading after half hour does not seem right',
#  'i ve been trying to download this app for more tgan 24 hours this starting me to think why bother feel its waiste of my time ',
#  'power changing',
#  'am having issue signing in',
#  'trying to download and it not happening sucks',
#  'unable to join',
#  'good app',
#  'i will change my rating if someone explains how to record meetings and how to open ppt files ',
#  'vvvvvvvvvvvvery good app must download it',
#  'will not work on android 5 0',
#  'i have samsung phone and this app is not cooperating with it it says its not availabe',
#  'i can hear nothing ',
#  'i think its too heavy to be run on phone e my phone restarts every time try to join meeting ',
#  'i can hear',
#  'does not work properly too slow no hd voice',
#  'when try to uninstall zoom app it reboots my phone every time ',
#  'zoom sucks there should not be time limit at all no one should have to pay anything to use this app at all ',
#  'stucked all the time',
#  'use for sometime don like it lots of lags sometimes drops and unreliable ',
#  'every time ve had to rely on this for business because client preferred it it ha skey me down ',
#  'absolute garbage of app one time can hear next time can talk it not like we re trying to teleport and it doesn work it just the basic functions that this app is lacking ',
#  'wouldn download',
#  'won even download',
#  'i think it was terrible',
#  'absolutely useless the most pointless conference call app ever really angry that you can hear anything unless you dial is separately and then that doesn even work ',
#  'heavy as hell no web based option stop forcing people to download useless apps',
#  'tried logging in from the app as well as web says network connection failed everytime',
#  'can download says pending ',
#  'sound repeat again and again',
#  'sound doesnt work whenever try to join meeting on the mobile app can hear anything ',
#  'happy',
#  ' hate you zoom oofff hate online classes',
#  'no privacy',
#  'very bad',
#  'bad',
#  'terrible app better to use google meet or something',
#  'it very harmful app to steal our data also don want to use chines app',
#  'worst',
#  'it horrible it very laggy and bad quality',
#  'every time network problem',
#  'best app',
#  'spy',
#  'it not installing in my laptop',
#  'chutteiya',
#  'bakkwassss',
#  'hanging',
#  'my video is not appear could get it',
#  'i am unable to access this app can you pls help',
#  'very bad app',
#  'very bad lacking to much problems',
#  'impossible to stay connected to meeting',
#  'waste of time',
#  'ewwwww',
#  'very poor have had all of my meetings this week disconnected by zoom during the meetings have reported this to zoom and only had generic reply am licensed user paying 15 month am very dissatisfied with this service and am actively looking for better service elsewhere would not recommend zoom at the moment',
#  'literal garbage you could pick any number of better options ',
#  'please make virtual background possible on android',
#  'im trying to download zoom on my macbook and the only option its giving me to download it is on mobile phone that ve not used since last october which has no sim no internet connection and not on it won give me any other options not even this macbook m on so it won download on this macbook not only that when tried to join meeting and put the audio on it said my macbook doesn support audio so got no sound had to go back to my ipad on which only have to click on the app to get into meeting you can even put clickable apps on macbook whats the point of this zoom app if it won download onto the machine you re actually on ',
#  'useless was to join zoom wedding event tried for 45 minutes to download the app got supreme runaround not geezer friendly ended up playing solitaire never got the app ',
#  'i used it once and then uninstalled but my google play store still shows it as installed stupid that can remove it ',
#  'it killing students lifeee 50 of internet is wasting for this',
#  'hangouts exists',
#  'reinstalled the app two to three times but its not opening ',
#  'aa thoooooo jeena mushkil kr diya ',
#  'in pc how we can installed zoom app please tell fast because my online class is going on',
#  'i face dificulties to install this app on laptop why ',
#  'hey could not sign in to my zoom app please tell me something to resolve the problem ',
#  'i cannot get signed in or download the app locked out for 30 then went back and could not download the app on my phone and cannot sign in with my google account or google play have meeting tomorrow at 4 pm looks bad for me am using samsung 10 and gmail address should work said it is invalid and does not work with password change will give one star for getting lost and no help ',
#  'i have tried and tried to get on to zoom meeting with no luck over it ',
#  'worst app it is not working in my phone ',
#  'i have installed this app on my huawei android phone in play store it says installed but can see the app icon on homescreen if anyone can help',
#  'i kept on installing it google verifies my address but the app never surface on my phone ',
#  '5 lakh plus zoom login details up for sale on dark web ',
#  'it cannot even get into your computer',
#  'not good',
#  'i just dont like it',
#  'sharing data is very bad ',
#  'supposed cancelled my membership and they charged me for another month will give you 4 stars if we solve this ',
#  'poor audio and poor connection and why won it work for connex laptop please tell meeeee now it must work for all device',
#  'porque no puedo instalar esto me sale que lo tengo instalado pero no es asi no lo tengo instalado en ningun dispositivo',
#  'it takes too long to download your tablet',
#  'i have installed zoom cloud meetings app from google play store and it is showing as installed am not able to find the location where it is installed and how to activate it zoom helpline chat is not understanding what my issue is can any one inform me the path where the app is installed ',
#  'this app is joke not working on my android smartphone cannot get audio or video ',
#  'this app is horrible it poorly works and steals your information',
#  'hello c ',
#  'i am unable to watch it on laptop ',
#  'kaise iske profile banaya',
#  'it is very bad app plz delete all from your mobile',
#  'not safe',
#  'why cannot install the app',
#  'zoom app is downloaded in my mobile but unable to connect in laptop',
#  'terrible',
#  'when try to join meeting can see everyone clearly but have no sound and can not enable my mic went through all the troubleshooting can think of uninstall and reinstall app still doesnt work enable all app permissons for the app still does nt work check if mic is not muted checked try pushing the enable audio butoon in app does nt work just nope uninstall use something else that works',
#  'never ever clear voice during meetings and continuous disconnection during all the meetings ',
#  'dont it will be not secure ',
#  'totally confusing setup and came up with some gobbledegook error message in computer speak fairly typical really of software geeks is it zoom or zoom cloud for example who knows does it work with opera browser apparently not when you download it it doesn even confirm it has successfully installed ',
#  'i am trying to download in my pc but it automatically down load in my mobile plz guide me',
#  'hell app uses most of the mobile data',
#  'i cannot get this app onto my home screen so bad have so many meetings and cannot participate in any so lost tried all the waysi knew',
#  ' ',
#  'govt of india declare is unsafe also found out that hackers to sell zoom video app data for approx 23 lakh that around 29 987usd this app is not safe at all am terminating my account right away hope they didn sell my data already boycottzoom',
#  'i have downloaded twice asked for password once how do log in for meeting cannot work out how to get in to zoom ',
#  'since the update continually drop out of the meeting am in really disappointing',
#  'no audio permissions granted checked in settings tried connecting headphones via bt or jack neither works doc page not helpful as it seems to show old information ',
#  'not safe it chinese item that doesn last long',
#  'bad experience',
#  'chines app',
#  'oh this made mess of my phone it reset my setting in all my apps had to use this app to do chat with my insurance to find my other apps on my phone were all screwy to make sure nothing was left behind of this thing did reset on my phone over it ',
#  'in this app recently many hackers activities going on newyork time is say many accounts data is cheating this app',
#  'just take it down for few months so students don have to deal with it',
#  'do not download downloaded this on my phone and it has ruined my phone uninstalled with 12 hours but since downloaded the app it has restarted on its own repeatedly talked with service technician for my phone and the service rep can do anything but tell me to take it to repair place ',
#  'super laggy to the point of being unusable meeting recordings also fail to load halfway through super annoying ',
#  'cannot even install this app please help ',
#  'tried it on two tables and two laptops and cell done does not work on anything have don waist your unless your device is less than two years old ',
#  'this sucks',
#  'bad so bad',
#  'no',
#  'hallo warum kann ich die app nicht auf meinen leptop benutzen er zeigt mir immer an das es auf mein handy ist',
#  'how do sign into meeting',
#  'can get into meeting or start one ',
#  'still there should be zero rating',
#  'badest app ever',
#  'it doesnt work on my laptop and it says must use phone ',
#  'could not get it to play and very irritated what collosal waste of time',
#  'doesnt work',
#  'i downloaded this app to use for school and it tells me its installed but there is nothing is there something wrong with the app what should do now cause need it urgently for school how do accept requests if just sign in without downloading the app can fix the problem and let me know ',
#  'horrible app',
#  'ko thể tải về đc đã tải từ tối qua mà bây giờ vẫn chưa về dở tệ',
#  'after 2 days of downloading can find the app even though it says suitable for my mobile and pc',
#  'hi it shows installed but the icon does not show anywhere on the laptop screen can somebody please help ',
#  'faltu app fake useless app hate this app',
#  'how use it on pc',
#  'it too heavy as an app',
#  'hi dev have been using this for an year and never had problem after the phone got updated to nougat the app is making the whole phone audio to mute once start the app had to restart to get the audio back am using miui on mi5 appreciate if it can be fixed ',
#  'aà',
#  'basic features don work correctly particularly link handling you can click meeting url and have the app pop open and audio it will route meetings to bluetooth a2dp and there no way to transfer to handset even if you have headset the ui is also unclear g the speaker control and annoying speaker is on by default finally ui components are hinted in such way that security managers lastpass think meeting numbers are passwords and try to save them ',
#  'i solve math problems with my brother and the picture is always out of focus and there is no way to readjust the focus of the camera miserable ',
#  'no',
#  'audio issues couldn hear word that was said in the meeting ',
#  'amazingly the linux experience has gotten even worse it seems to force itself to all virtual desktops with no way to disable it previously only saw that with wayland but now xorg is doing it too any time share the remote ends shrinks down to an unusably small window that makes it nearly impossible to see any listener reactions mic volume seems to be some form of dev random every time you start the app which is always because killall when m done overall unimpressive 1 star',
#  'the app is simple to use and configure however once disconnected it impacts the data connectivity',
#  'not sure how it work at meeting id ',
#  'choppy',
#  'zoom ain working in uae guess could you please work on that so much need it',
#  'it is usefully',
#  'why do you need access to user google drive it may be having personal information ',
#  'good',
#  'it is an okay app but could be better because when any participant joins from their android phone their audio is so low if they are using the loudspeaker of their phone think it is an issue with zoom audio algorithms on android devices since other video calling apps don have the same issue the audio gain needs to be increased also when anyone tries to join don make the default audio method is prompt asking which audio source to use since very often non techy participants are expect',
#  'when am clicking the sign up button it shows pop up bar which contains message that my internet connection is failed to sign it up don know what to do further please help me with your kind suggestion ',
#  'the permissions this app requires don make sense with what it does am not comfortable it poking it nose every area of my phone have to use it for one meeting once done am getting rid of it ',
#  'tried using it on multiple devices and was unable to hear the speaker who was not muted according to other meeting attendees very sad to miss this meeting ',
#  'my professer uses this to do online lectures usually use it on the computer but since it broke had to use tablet instead the audio doesnt work when during the meetings so can hear his lectures',
#  'the description mentions screen sharing however am not able to find figure it out so far its basically just watered down version of facetime ',
#  'the app is good but too many problems in hearing persons clearly',
#  'nice one',
#  'good',
#  'didn auto mute by default when joined despite showing an indication that was muted an absolute deal breaker adding star because they seem to care about the app and contacted me to address it ',
#  'doesn work on my s6 edge it used to work before m guessing it is related to an update in the app can sign in but none of my contacts show and keep getting this message constantly appear and disappear that says click to re activate your messenger of course nothing changes when try to click on it tried clearing app data cache reinstalling and nothing works useless when it worked it was particularly annoying to answer call on the computer also running zoom but the phone kept on ringing and ringing ',
#  ' ',
#  'get lost',
#  'works ok but the audio are not coming out on my bluetooth headset just working down the wired ',
#  'ever since ve updated it it won work please fix or help use samsung tablet and everyone uses this app in my meetings so can change it really need to attend my meeting please help thank u',
#  'can download',
#  'user experience leaves lot to be desired even after video training mobile app and computer app totally different functionally great potential but not intuitive',
#  'i don recieve notifications only when open the app they already',
#  'it not very user friendly the little buttons at the bottom when m using my tablet it messes with the buttons at the bottom of my tablet so whenever you go to do video share or mean screen share or something like that then it either shuts off or the person can hear you or it just hassle it it really really is it not very user friendly',
#  'its sad one of my important meeting got recording with mp4 but there is not video in it don know what to do now ',
#  'you can screen share all types of google drive file types you can see yourself on video nor flip you camera from front to rear while presenting like you can on ios that was always useful during meeting left ios for android and now forced to use desktop verison to meet because of the lack of features on the mobile app compared to ios which sucks because love to walk and talk what up with that zoom ',
#  'i in uae and m not sure if that is the reason why cannot sign in keep on connecting but never connected would appreciate if you can guide and give me any solution with this ',
#  'price high in india ruppes not support my review ',
#  'السلام ورحمة',
#  'app is totally useless without working push notifications can believe an app from company of this size can get something as simple as notifications right mine don work unless have the app open and even with it open in the background it stops receiving notifications after few minutes when logged support ticket with zoom got told it could take weeks to sort how m supposed to tell that to all my staff who use it ',
#  'used it for year each time there is software update to my android 5 my data records disappear so it useless as long term health monitor other than that it was great ',
#  'its good ',
#  'все отличающие от конкурентов возможности платные при регистрации сообщает укажите действительный адрес электронной почты хотя адрес рабочий и введен правильно после отправки жалобы через форму обратной связи никакой реакции ни уведомления о получении сообщения или ответа в приложения для windows ввожу email и пароль после активации конфигурация zoom rooms не настроена для этой учетной записи ',
#  'basically works but pales in comparison to the iphone app can figure out for the life of me how to save meeting id even though ve connected to it dozens of times am logged in lots of little quality of life improvements in the ios app that just are not present in this one would be much happier if they even add drop down for recent meeting ids this exists on literally every other platform zoom supports as it stands the only way can connect to meeting is to manually type the id in everytime or open my calendar find the meeting and click zoom link inside of the description ',
#  'zoom has rencently started disconnecting my connection on samsung galaxy 9',
#  'first time using the app on my pixel 2 and it caused the phone to shut off due to overheating before that sudden interruption the call was fine ',
#  'recent update has caused app to not work with my chrome book version 64 0 3282 190 use zoom frequently and need to find work around or solve the issue ',
#  'views clean enlarges well would be nice if chats can be shut off chats between attendees annoying as they cover to much of the screen too much on cell phone ',
#  'my friend got on and we tried to video chat it it started squeaking really loud couldnt even hear her',
#  'horreble',
#  'sorry but could not hear anyone in the meeting ',
#  'app having problem in opening',
#  'when it works its good cant ever get the audio to work automatically or at all this hate im missing meeting chats etc have an android and its very difficult ',
#  'extremely long download on mobile it not too stable video cuts out sound has static on samsung note 8 ',
#  'nice app but could have been lighter than 37 mb',
#  'impossible to download app several attempts made ',
#  'not getting notifications for new messages',
#  'rxffd trd tx tx rrrxfxxfxftdxxxxdxxt yeah ball where about how you about',
#  'this app works awesome',
#  'i just downloaded zoom onto my tab 3 so that could participate in training webinar however when tried to open the app goot an error message not suppported on this device really ',
#  'couldn get it to complete the down load just keeps running and running ',
#  'was asked to use zoom for interview ended up using whatsapp video call sorry',
#  'not good',
#  'never notifies me of messages checked my settings and it is set to notify me even when the desktop app is active but it still doesn work ',
#  'to long to download',
#  'i so disappointed that the free version kicks you out after certain amount of time and asks you to pay 15 month they would be better to add extra features to upgrade because now don even wanna use it otherwise call quality was pretty good ',
#  'please add samsung and google pen support to the whiteboard share feature ',
#  'no other apps use the camera just view them but cant start my camera ',
#  'very slow for call in uae need to know person who read messages or not voice and video clarity level need to increase connection issue even full coverage wifi do work more ll suggest all my other team ',
#  'with free space can not easily still download the app eating up my data can not get it downloaded its getting frustrating ',
#  'please update the app as it consumes 29 of my phone battery',
#  'my only wish is that they would not auto start video the moment you opened the app you re going to get people fired ll update to 4 5 stars once you do as google hangouts does to verify you are ready to start into conference and can adjust your settings ',
#  'no way to find people',
#  'doesnt find gmail saved contacts most android users should know not to save your contacts to the phone but to your gmail account it seems zoom only looks for contacts saved to the phone because it cannot find single contact ',
#  'good',
#  'i loved the app in the beginning as it allows for more users to group chat and video conference in than most services however in the last few weeks or months for that matter have not been able to receive any of my notifications and it very frustrating will go back and have days worth of conversations that ve missed ',
#  'was not good experience for me very choppy video and sound was on good connection ',
#  'mute doesnt work on pixel was in meeting with my team only to find out everyone knew was in the shower because they could hear the water running not cool ',
#  'can not get on',
#  'not able to download its loading for long time',
#  'good but the privacy policy is very scary',
#  'warning latest update rly buggy getting notifications but no messages are updated and shown in app itself force close fixed this but unsure for how long following update made things even worse way to break good messenger devs ',
#  'this app took me away from netflix ',
#  'ok',
#  'poor reception',
#  'video quality is good',
#  'its not useful',
#  'app has so much potential but it so badly constructed and has so many faults it makes it too frustrating to use ',
#  'latest update broke the tablet view ',
#  'audio quality is poor integration with google calendar is good but does not work with work profile on phone so cannot sign in to zoom from mobile app overall below average experience ',
#  'there are many bugs admin please fix it this is very useful app',
#  'chettha app',
#  'cant install',
#  'when m in meeting my video camera pauses when type in the chat ',
#  'i couldn click the share screen button on the pop up',
#  'just so everyone knows these geniuses have never used this app so they set the default to audio on and video running',
#  'tried to download the app wanted to join meeting but it kept on requesting ',
#  'y cant hear the sound',
#  'often getting disconnected',
#  'sux',
#  'how can change my device',
#  'it has been working okay on my desktop until recently whenever set for meeting when its started am unable to use it since when click to open it hides on the task bar at the edge of the computer screen what could be the problem need help because there alot that am missing ',
#  'भ गकखव षव ल ',
#  'how to download it on pc',
#  'an android user here and and cannot connect to the audio at all although have given every permission bad app',
#  'i just can download it it loads and loads ',
#  'problem in installation',
#  'after installed the app couldn find an icon to open it ',
#  'says app will be added to device soon when and where is it ',
#  'at the moment wouldn recommend this to anyone please put tutorial up so us elderly people can understand it cant even tell whether m on the right zoom',
#  'can get this downloaded to my computer need some help please and will be happy to change rating ',
#  'too many steps to get this installed',
#  'cant install in my hp laptop with wndows 7 0 automatically it is installing in my android phone cant fix the prob pls help',
#  'wont let my daughter get it she need it for school she wants to call her friends',
#  'wagner mendes tive grande dificuldade de abrir link mesmo caiu algumas vezes sisma de ficar ligado ao meu telefone quando preciso que fique ligado ao computador gostaria de poder ter um link para ligação direta pois me parece que sempre tenho um caminho ser percorrido ',
#  'does it not work for apple ',
#  ' can you please tell me how to uninstall zoom as installed it incorrectly and now need to start again thankyou ',
#  'installed zoom on my samsung android phone which seemed to work fine then tried to install zoom on my lap top as wel but the download kept telling me it was already installed asssuming my phone so in my wisdom deleted it from my phone then attempted to install it again on my laptop nice try the download window still tells me it is downloaded already which know its not how can download it on my laptop as my only download ',
#  'i want to install this app in my laptop but failed please guide me',
#  'if t would ve worked d tell you',
#  'zoom not working liky before',
#  'it lag to much',
#  'wsf',
#  'just slow for me',
#  'cannot get into the meeting ',
#  'que des problèmes de son sur portable et sur ordi ',
#  'why only 40 minutes but whatever the schedule time should be given to the client for meeting 40 min is not enough for meeting ',
#  'not able to sign up as am unable to set password to login',
#  'taxiways 6',
#  'it takes up your batture and it does not insatll or work this app if it work better and not so hard would use it more ofthen',
#  'it be great to come with instructions while new to meetings and just as installation occurs ',
#  'need to have more time to let people interact with their group meetings more',
#  'frequently getting stuck',
#  'dont know yet',
#  'very poor directions',
#  'unable to share while in meeting ',
#  'unable to download the app',
#  'hello sir',
#  'retr',
#  'i barely getting into this app ',
#  'no good for mi',
#  'sound was terrible',
#  'good',
#  'does not always work perfectly',
#  'can understand the process',
#  'zoom share feature is lacking the interchangeable share must exit one before using the other share options zoom should allow switching between share features also when share youtube video zoom mobile only display the link this is bad please fix this so the shared youtube thumbnail is displayed this is the industry standard no screen capture whiteboard cannot import images or pdf files cannot share files no dynamic share switching ',
#  'finding it hard to download app',
#  'no way to test or change audio settings',
#  'taking hours to load',
#  'what is the 3078 error code ',
#  'i unable to download it',
#  'the android version of this app is terrible when creating meeting it is not possible to sync to your outlook calendar have seen screenshots and articles showing that you can do it on ios app when create meeting it doesn add to my outlook calendar have to do that manually and that annoying the video quality is good as is the audio quality but the connectivity to third party apps is bad please fix this to make it on par with your ios app ',
#  'meeting was freezing and coming in and out',
#  'app keeps crashing closes suddenly repeatedly throughout 20 minute call without notice this happens while hooked up to an ultra strong wifi this does not happen on the web version just the mobile app please contact me with any advisement ',
#  'for some reason the app keeps kicking me off of the call ve been on for the last couple of days like every couple of minutes no issues when access the same call on different device though ',
#  'zoom notification won go away unless restart my phone constantly says m in meeting even though it clearly ended',
#  'too confusing can figure it out ',
#  'zoom crowd meeting',
#  'how do watch recording from link using the app',
#  'i can hear audio ',
#  'is this available india location',
#  'it doesn work properly in sudan',
#  'the audio doesn work properly ',
#  'ihave already installed in my phone but couldnt able to install in my pc',
#  'i can hear audio reinstalled app and did all the troubleshoots m in class where need this app once week and it would be nice to hear what being said headphones don do anything',
#  'okay so we are on day 2 of our meetings theres only 3 of us in the meeting keep getting dropped have to rejoin the meeting like every few minutes the sound was echoing computerish help',
#  'share screen refuses to share video or sound in the mobile app there are no options to optimize sound and video in the mobile app basically the mobile app sucks ',
#  'wo',
#  'sound stopped on both aps phone and computer',
#  'good communication experience but ui ux is truly horrible',
#  'i would like to give 5 star when you add india country in zoom app ',
#  'please update the app as it consumes 29 of my phone battery',
#  'wont open or let me download ve used it before ',
#  'the latest app version keeps on crashing please fix',
#  'it is becoming more unusable when on zoom call it still allows your mobile phone to ring over the top of the zoom call must be the only person who uses the zoom phone on the phone looking at ring central it getting more unusable the best is now if you are on zoom call and another soon call comes in forget about the app is so stupid it doesn know your on call and it runs anyways louder than hell now m deaf ',
#  'problem downloading the app',
#  'not soo good voice was disconnecting between program and also disconnect itself after some time then it again reconnect between the program',
#  'ui outdated emojis not showing when sent from desktop says just emoji notification doesn always pop needs more work feels on mobile like software in beta ',
#  'just okay',
#  'somwwhat works often buggy and annoying ',
#  'i am trying to download the app however if has been over an hour and it is not downloaded missed very pirrant meeting ',
#  'not sure why there is no way to simply share meeting link you have to go through all this brouhaha to pull up the link just put meeting link so that it is easy to grab and copy what so hard about that concept ',
#  'i cant hear anything',
#  'when it my time to connect with my coach if click on join my phone automatically goes black can hear his voice can see any picture have same meeting in less than 30 miniutes need help',
#  'not to the mark',
#  'sometimes if open the app on my phone running android 9 and either call in or have the app call me am unable to mute or unmute myself the worst is when can mute myself even if mute myself in the zoom session and on my phone call ',
#  'i also have the same issue can hear the other person without headphones which is very inconvenient pls fix this thank you',
#  'it would be nice if you could change your meeting id without having to upgrade ',
#  'the sound qaulity',
#  'how do record on zoom app using samsung galaxy phone ',
#  'it never lets me in when im sent an invite to join meeting the app never downloads ',
#  'fair',
#  'can hear the other person',
#  'i think its good for metting on the live',
#  'hi may know why cannot initiates chat or calls haave downloaded the apps and log in using sso but it seem like it doesn not working',
#  'after android 10 update on my pixel xl 3 zoom will no longer play sound on my plantronics plt fit via bluetooth zoom is working on my pc with usb headset the android app is on the google play store so it should play nice with google branded product my bluetooth headset is very loud on other apps so know the issue is not the headset there seem to be only two modes on the android app when the plt fit is connected via bluetooth one shows the bluetooth icon but plays through the phone speakers the second plays sound through the external speaker to me it appears that the bluetooth icon is mislabeled should there not be three modes external speaker regular speaker and bluetooth speaker ',
#  'had to reinstall',
#  'why share your screen option is missing ftom the update please rectify the issues ',
#  'after updating to android v10 incoming calls no longer ring not much good for phone system ',
#  'loud speaker not working on oneplus6 from latest update please fix asap',
#  'great to have meeting with multiple people but find the audio quality is lacking quite choppy',
#  'bissnis',
#  'just started using it its okay',
#  'st',
#  'not too bad',
#  'decent app definitely useful when you have some down time only thing is it won let me upload profile picture ve tried multiple times but all it tells me is the connection failed and to try again later hope this will get fixed in the near future other than that it a pretty ok app ',
#  'the app works well but the android version has less options then every other platform ios mac pc linux use this app to collaborate with my team but can see only 4 people per screen so have to scroll through whereas they can see up to 49 every other platform seems to also have virtual backgrounds which is missing on the android version ',
#  'cannot share screen on android ',
#  'video and audio quality becomes poor',
#  'erteffv',
#  'ok fine call',
#  'सह चल श द ध बन ',
#  'great apps',
#  'its always slow and lagging',
#  'h hello',
#  'the app seem so cool but you guys need work on quote message and the connection issue',
#  'but stays on in background with no way to exit ',
#  'i facing an issue unexpected error code ',
#  'good ',
#  'good convesation',
#  'for mobile use current version is good in desktop old version was much better then new version',
#  'i love this app in all of its forms desktop pad and android what it suffers from the most on the android platform is battery life will be on 1 hour meeting and loose at least 55 power ve been on meetings that lasted longer and had to leave the meeting abruptly due to my phone dying ',
#  'high quality conferencing but the app design is so unintuitive to new user really hard to use which is shame given how great zoom meetings are ',
#  'interesting',
#  ' ',
#  'nice app',
#  'hi is there any way to play mp3 file during meeting ',
#  'love this on desktop as am able to record audio video of meetings although mobile app asked permission to record don see anywhere where can start stop view recordings that are made help ',
#  'why is your app accessing my camera in the background seams bit weird',
#  '7 15 2019 zoom we still have issues with low audio levels in our conferences from mac tablets and some mac notebooks and all in ones still having overdriven mic with my bluetooth earbuds which use popular audio chip 10 6 2018 zoom your app is irreplaceable and has done great things for lot of people please polish the functionality in the linux version and fix issues with super low or overdriven audio there seem to be hardware issues or automatic gain control issues on so many devices ',
#  'mr ',
#  'i think its ok just that the ui is dated could use an upgrade ',
#  'it doesn have record option ',
#  'on okay',
#  'not working while some apps use screen overlay',
#  'after updating to android marshmallow zoom doesn run anymore can you help on this zenfone 2 android 6 0 1',
#  'us120263',
#  'ok',
#  'i love this app and use it alot but it does not have the feature to upgrade to pro please help would love to be able to zoom longer then 5 minutes',
#  'the app is good it needs to show more callers on the same screen at the same time ',
#  'no volume and im having hard adjusting',
#  'aight',
#  'keep on disconnecting',
#  'it cut off and sometimes can connect',
#  'me gusta el nick por defecto que tiene la app al momento de hacer un join lastima que no puedo subir la captura de pantalla muy buena la app ',
#  'speed',
#  'if audio and video can be in good transmission due to bandwidth problem audio should be kept in good condition esp in meeting circumstance ',
#  'size of this app is to much',
#  'thnx',
#  'not working in uae anymore ',
#  'heats up the device crazily',
#  'app continues to restart and drains my battery so uninstalling ',
#  'it does the purpose it was created to perform ',
#  'good innovation',
#  'the app keep on closing and launching itself was not able to attend one of the meetings so annoying',
#  'ok only',
#  'not bad',
#  'even though allowed access to everything zoom wanted access to thought it odd that when joined meeting both video and audio were off by default on nexus the app does not seem intuitive perhaps it behaves differently on other phones the biggest problem had was losing audio when someone called me while was attending video meeting had to leave the meeting and re join in order to get audio back ',
#  'we use this app all the time depending on your internet connection you can have meeting without problems or mess of meeting best meeting is on stable fast speed internet connection the biggest problem with this app is the fact that you cannot use your computer for other things such as using different webrowsers or opening other documents at the same time it running because it will freeze your screen and make your meeting living hell then you look incompetent please fix this ',
#  'please disable auto rotate also option to disable speaker phone on meeting join ',
#  'good',
#  'am giving 3 stars because when using the app after like say 30 40 minutes then it gose off telling you that free period is over please do something about it thank you',
#  'works pretty well but ui is clunky in particular the click to speak circle is misleading tapping anywhere on the screen toggles the microphone making it too easy to do this by mistake ',
#  'i yet to try my conference meetings ',
#  'audio became very crackly and was breaking up this occurred about half way thru the meeting on our last two meetings healcare groups',
#  'so cute',
#  'i just installing',
#  'seems to work well just tried it out with my friend for 15 mins or will update my review once ve used it for more considerable length of time ',
#  'if like to see few more features attend meetings where more than one speaker is relevant and while switching focus with audio is perfect sometimes there are meetings when d like to be able to pick more than one speaker video feed to pin so could have 3 4 or 5 people enlarged and the remainder as scrollable thumbnails it would also be nice if when another attendee sends private message could click on their user name to take me to their video ad well instead of having to put my glasses on and read through every user name until find them most people don use familiar names and hate to respond until visually verify who m talking to ',
#  'joined meeting on my tablet today and couldn hear it had to switch to my computer will have to try the mobile app again ',
#  'i think room has to be made for more participants attending meeting say like 1000 participants attending meeting or more ',
#  'accurate feedback',
#  'it problem freeze and reconnect',
#  'pixel 2 pie overheats shuts down in the middle of video conference all background apps were closed prior to using this app connected to lte tower across the street full signal had to switch to my old motorola nexus 6 pie wifi to complete the video conference which worked great and didn cause any overheating issues ',
#  'ok',
#  'good',
#  'too big',
#  'but who knows at least no strangers casing my pad ',
#  'app works for video conferencing fine however it knocked out the mic for speakerphone on all apps had to uninstall on s9 ',
#  'testing',
#  'it not so steady on chrome book and when shared screen it just kept crashing hope they get fix because have always preferred zoom rather than skype and need it for work ',
#  'it would be waaayyy better if they just allowed you to do simple screen share without having to be in photos videos or specific web page need to be able to share other content located on specific apps on my phone and m not able to do that ',
#  'how can record my meeting through android phone ',
#  'love it',
#  'it disconnects lot while having poor connection not quick on reconnecting again like skype if that is resolved then it a good app',
#  'hoping this works',
#  'every 30 minutes app stops and needs restart all over again ',
#  'is very encouraging for communication',
#  'good even if sometimes no connection at all overall ok',
#  'device onall books',
#  'even though internet connection is prefect it is showing all contacts offline its happening since from last twoydays',
#  'this app would be perfect if could down load it to my nextbook',
#  'i dont know why apple version can send receive messages and this one cant',
#  'thanks for your help in this matter',
#  'partially okay',
#  'kept dropping out from otherwise ok session over wifi network not sure if it the app or the wifi coverage ',
#  'app restarts lot when you open chat and constantly has to reconnect and update the chats even when you have received notification from the app ',
#  'will this work as zoom room controller instead of and ipad',
#  'this is good tool to have once it get installed very useful ',
#  'can get into groups other than that it seems ok',
#  'thanx for add remove and block for noise contacts',
#  'i had trouble signing in could not get my mic to work found out was in driver mode ',
#  'not evem can sign in link spire',
#  'don know what m doing yet',
#  'new user have problems joining in on the scheduled webinar ',
#  'always it is in connecting ',
#  'dba one team one dream oohh yess',
#  'good',
#  'ui is really poor ',
#  'good for meetings',
#  'i just had to uninstal to see if there a problem with installation am not able to sign in when open it can even reset password if that the problem please fix ',
#  'high cpu heat confusing ux the need to specifically accept audio video device make conference start slow and cumbersome joining before start will not ask these permissions and you ll sit waiting forever with muted audio without knowing it already started ',
#  'zoom app cannot be updated on my device verizon tablet',
#  'great app but notifications have stopped working since last update my company use this app for most messaging so have missed many messages until have opened the app',
#  'keeps logging in and out on its own',
#  'how can access sd card files ',
#  'good',
#  'a wonderful meeting tool to network with on social media ',
#  'earlier sign with company domain sso worked fine now it opens in browser and it not mobile friendly',
#  'quality is hit and miss first three zoom meetings were perfect the last two were absolutely dismal ',
#  'has the update for today had an issue with opening zoom us meeting links no longer by default for the past 6 months meeting links would open directly in zoom after was initially asked whether to open on the web browser or the zoom app today update now causes links at least on my galaxy s9 to open only on the web browser and have to wait for button to show up on the web page in order to launch the zoom app please look into this as am guessing am not the only person experiencing these unnecessary and cumbersome additional steps ',
#  'more',
# ...
#  'useful if ads are shown less so irritating because of ads',
#  'thank',
#  'no espiriense',
#  'too much background noise',
#  'its well thought out even though have limited access to certain features would love to know how to access them ',
#  'i can set my profile picture of my own it always shows unable to upload the profile photo so fix it soon ',
#  'need to make it more simple and fast with reducing app size then it can be more popular',
#  'my experince was best with zoom apps ',
#  'never used it before but heard good things about it',
#  'didnt need the service the version got from play store would not allow you to terminate account had to sign in another way to access account didnt use it so can speak to how service us just app maintenance',
#  'it ok',
#  'great',
#  'do you have pic can see and show for her to get chance to try and learn how to use the same thing with couple of girls who wants to be here playing joke about the way we have always been able to get together for little bit of what you want to do',
#  'good',
#  'good',
#  'missed some words',
#  'gud',
#  'good platform like anything else in this world it has its issues but overall performs pretty good',
#  'good',
#  'update with display over apps',
#  'pls how does it work ',
#  'took way too long to install ',
#  'it great until last meeting today can enter meeting always show error 5003 can browsing even open youtube something is blocked this app dunno why had tried restarted shut down and reinstall still nothing',
#  'there were some disturbance in call quality and network ',
#  'the volume is too low ',
#  'it works very well but drains battery quicker than any other app have ',
#  'best app for meeting',
#  'i dont like the 40minute cut off for meetings minimum time should atleast be 1 hour for unsubscribed meetings',
#  'it pretty good but have problem that each time enter the app it asks me to sign in again hope to find the solution of this problem',
#  'good',
#  'would rate higher if had all capabilities that ios has ',
#  'still need to improve taking time for loading',
#  'how can one record meeting ',
#  'not bad',
#  'great for video terrible quality for audio calls ',
#  'please provide the option of recording',
#  'fades in and out quite bit in the middle of meetings',
#  'still learning and getting use to the tech of it have been blessed to both use and take part in many bible lessons and bible discussion which save traveling time thank you so very much ',
#  'not good so far',
#  'unable to download from playstore',
#  'thought the audio could be crisper ',
#  'good',
#  'good app',
#  'good',
#  'good',
#  'annoying to turn off log out also biggest battery hog ever ',
#  'my country is not available in this app',
#  'partially good',
#  'all the well but sound not working after join meeting',
#  'it does its job but would appreciate it if there were convenient or if m missing something more intuitive way to keep list of meetings you re signed up for and preferably have the app start itself when meeting starts the cherry on top would be the ability to have different settings for each meeting ',
#  'good',
#  'good',
#  'yes better than others but financial is high for long talks and meetings',
#  'good',
#  'find it difficult to use ',
#  'good',
#  'zoom repeatedly disconnected and then reconnected ',
#  'great',
#  'voice un clear during meeting',
#  'it doesn work with android auto which makes zoom calls while driving pain while on call or webcast the volume won come through the car speakers and it doesn use the car microphone ',
#  'good application',
#  'good',
#  'it good',
#  'good',
#  'can use speaker phone or bluetooth speaker',
#  'mobile version could be improved ',
#  'excellent',
#  'ok',
#  'good',
#  'nice',
#  'it keep on cutting out when speaking don know why',
#  'good',
#  'needs improvement',
#  'good but voice problem',
#  'handy but not always stable and often time limits the calls with cut off',
#  'just started using it think its really good',
#  'app restarts lot when you open chat and constantly has to reconnect and update the chats even when you have received notification from the app ',
#  'very good app',
#  'very good but m getting awful video issues where it is clear for 3 or 4 sec then looks like static is overlaid on the video and you can see anything hard to explain without screen shots ',
#  'buggy and confusing though works better than most of the others',
#  'sometimes freezes but this might have lot to do with my connection it takes couple of attempts before can actually get connected ',
#  'there should be mode available in mobile zoom where user while on conference meeting should not receive any call or let say auto reject all incoming calls ',
#  'good',
#  'its very good app but it can save your meetings',
#  'hi team it a wonderful app for scheduling joining meetings but the issue was facing after recent update speaker on is not working previously when we use speaker on the audio was out and we were able to place the phone on meeting room desk so everyone use to listen and respond in meeting but not sure after update lost audio out option option is still visible for speaker on off but both works same can it be fixed with update if so am very much happy and comfortable with this app',
#  'like it help me do my stuff',
#  ' ',
#  'video and audio cutting out and disconnection',
#  'nice ',
#  'the app is good only for screen sharing the backgroud changer while on video is the worst and also there is very much lag even when both have best wifi',
#  'i wish could hear the meetings m invited too really think this is great app just can hear anything at all would love to be able to use it ',
#  'sound difficulty ',
#  'great',
#  'sometimes unclear',
#  'network should be strong',
#  'good',
#  'audio issue after entering the meeting there is no audio heared for couple of minutes even after trying to switch to speaker or headphone route also does not work after around couple of minutes or more the audio is heared this is 90 times happening needs exit re enterwhy is this audio issue not resolved properly as see many reviews are revolving around audio related which becomes the main feature of the application actually the audio quality is not bad after it starts working ',
#  'very power hungry',
#  'haven used it yet',
#  'good app',
#  'good app sometimes it buffers more than would like but still use it daily ',
#  'it a good image and essay user like it ',
#  'average',
#  'loved it',
#  'it good',
#  'better than skype which seems to have suffered some sort of slippage over the past few years lost star however due to difficulty contacting support staff ',
#  'in home entertainment',
#  'nice',
#  'to say the least',
#  'good',
#  'need more time',
#  'nice app for business helps connecr with your clients easily hv face to face interaction ',
#  'ok',
#  'amazing',
#  'ok',
#  'detailed',
#  'very very good',
#  'good good',
#  'it is fun be careful how you look or what is in your backdrop make it nice experiance ',
#  'very good app',
#  'great app',
#  'using for stuck broker webinars',
#  'over all strong app however there needs to be more thought in how certain features are implemented admit m new user of the app however found had accidentally engaged an annotation feature when trying to unmute guess buttons overlay slightly or something pressing back in android did not simply return you to your active meeting but rather to app settings it seems like worse yet pressing back button from this screen rather than returning you to your active meeting dumps you to home screen not hanging up thankfully rather than sending you back to your active meeting to me this is rather insane had legitimate issues getting myself unmuted in time for my turn in my meeting eventually after ran some where else to offer my thoughts walking back found that there was return to meeting button on the primary screen of settings but the back button functionality is extremely poorly thought out ',
#  'i want to record the meeting how can do it please suggest',
#  'this app is very useful for learners and schoolers ',
#  'good app',
#  'audio didn work had to call in ',
#  'satisfactory',
#  'thanks ',
#  'cool',
#  'worked like charm once installed excellent quality ',
#  'sometimes the sound is not coming through but the people are talking',
#  'thank you been able to make connections that would make otherwise happen ',
#  'works fine',
#  'very good',
#  'great helped me attend to some important meetings whom taking of course ',
#  'nice',
#  'good app to use',
#  'great app hope the new version fixes the bugs freezing and not connecting ',
#  ' ',
#  'useful',
#  'fantastic',
#  'super',
#  'great for international video conferences no dialup in the philippines though ',
#  'surprise me really',
#  'it little confused app but works fine to me ',
#  'just wondering how to remove someone from channel',
#  'good',
#  'good',
#  'i can send private messages to hosts of meetings including that will help lot',
#  'zoom nice',
#  'works well for meetings on the go',
#  'i have this on my cell phone why can i get it on my home computer ',
#  'cool',
#  'acchhaa hai',
#  'it takes too long to connect sometimes',
#  'good but if they removed the time limit will be perfect',
#  'clear and better than others',
#  'great but restricted in the uae',
#  'love it',
#  'very good',
#  'awe some',
#  'good',
#  'very nice',
#  'great tool for my business when dealing with developing long term long distance relationships',
#  'its great we can hold staff meetings and include staff that are off site',
#  'i ve been using other meeting apps zoom is one of my favourite ',
#  'nice app for meeting easy to use',
#  'awesome',
#  'good app for meeting and communication',
#  'good',
#  'pretty good',
#  'really like the easy functionality and clarity of displays keep up the excellent work folks ',
#  'good',
#  'in country region india is not there please add it',
#  'its amazing',
#  'is great app makes conferencing much easy',
#  'i use this app to joining conference call exallent very good app',
#  'its best app so far just need small improvement in sound quality ',
#  'the app is good to go love it',
#  'excellent',
#  'good',
#  'this app has offered me good service so far and have had many successful virtual meetings with my teams accross multiple countries keep it up team zoom ',
#  'superb',
#  'great convenient app',
#  'good',
#  'new user',
#  'probably best long distance presentation gateway ',
#  'good app',
#  'nice app thanks',
#  'excellent app and service ',
#  'this app works very well however notifications on the phone and android wear would be better if you could see who the message was from and the message also adding emojis would be nice ',
#  'need high bandwidth for video streaming ',
#  'good for meetings for lazy bums',
#  'love it but sometimes it freezes',
#  'great',
#  'i like it',
#  'learn more about',
#  'awesome',
#  'very nice alp',
#  'i like the zoom app very much it not very good on my phone because it makes my battery over heat ',
#  'nice app for confrrence call',
#  'i can see my friends and my school ',
#  'very nice app ',
#  'nice app',
#  'good technology move',
#  'i used once quality of connection was good then uninstalled from laptop and phone and now can install again it propose to do it on my devices where see name of processor of my smartphone copied twice and no possibility to installed on laptop in the list of my devices see another one phone it looked like me used another phone last time 1th of march but it was not me please fix it',
#  'too many stalls',
#  'i mean it just alright',
#  'it is very good app but had problem by this app it does not getting installed in my laptop when ever am installing its shows only androied option it is very helpful if you look after my problem',
#  'nice',
#  'how can install this in mobile and laptop also ',
#  'dear all how can use install in laptop this apps can advice me any one thanks mir aptab uddin dhaka',
#  'hi please once dowload these app am not able to access it keeps asking for gmail sign in but once sign it cant access the app what might be the problem',
#  'good',
#  'i installed it initially for learning on my cell phone samsung s6 however soon realized that must install it on my laptop instead now after having it uninstalled from s6 made few attempts to install it on laptop but it says installed how to get rid of this issue and install this app on laptop regards',
#  'please help not able to intall this app in my laptop already installed on android phone how can install this app',
#  'already have installed zoom cloud meetings application but couldn use it the application did not apprear on my ddevice desk top want use it now ',
#  'its good application',
#  'good',
#  'good',
#  'nice app',
#  'good its wonderful app',
#  'nice',
#  'good',
#  'i need help guys have installed this app on my phone now want it on my laptop but each time reach the place to instal it says already installed what shuld do ',
#  'great',
#  'how are you doing guys psalm 23 the lord is my shepherd shall not be in want he makes me lie down in green pastures he leads me beside quiet waters he restores my soul he guides me in paths of righteousness for his name sake even though walk through the valley of the shadow of death will fear no evil for you are with me your rod and your staff they comfort me you prepare table before me in the presence of my enemies you anoint my head with oil my cup overflows amen amen',
#  'it is amazing to talk to teachers',
#  'how to install this app in my laptop',
#  'it works very well for me one of the best app for video conferences without interruptions ',
#  'i am unable to download it to my laptop',
#  'how can download the app in computer when the app is already downloaded in the phone with the same account',
#  'i think this app is good but one major problem in this app is that while downloading this app it makes one to feel sick when was installing this app faced many problems but otherwise this app is really very good ',
#  'useful ap ',
#  'i liked it but unable to install this app in chrome book ',
#  'good',
#  'how to download it on pc laptop',
#  'i have this app downloaded on my phone and it works great but would prefer to have it on my laptop so can see everyone cant seem to download from google play onto any other device except my phone how do install it on my laptop ',
#  'good',
#  'beautiful development will sure recommend it to my friends',
#  'just okay not so great',
#  'best',
#  'awesome app',
#  'good',
#  'paytm is not going to launch unless we uninstall zoom ',
#  'good',
#  'very impress witn zoom to connect the whole world ',
#  'good',
#  'nice',
#  'works great for meetings',
#  'ok',
#  'i ve been trying to download the zoom cloud meetings app but couldn please what can do ',
#  'nice app',
#  'this is awesome but need an interface to teach new comers ',
#  'very good application',
#  'ok',
#  'hi paytm just forced me to uninstall your app as you pose security threat ',
#  'good app',
#  'good',
#  ' ',
#  'i am just beginner let me spend time with you then will be able to comment thank you ',
#  'i expect more from this app',
#  'nice',
#  'good',
#  'great ',
#  'i brand new to this so it took awhile to figure out the navigation not sure understand all the options will learn as go m sure ',
#  'metting call',
#  'great experience using zoom ',
#  'good app',
#  'gets easier each time use it',
#  'i have yet to learn more but will try it was good experience ',
#  'superb',
#  'clear stable',
#  'useful',
#  'great',
#  'lovely',
#  'nice',
#  'great smooth',
#  'easy to use good connection ',
#  'good',
#  'you can have online classes with this app and talk to your friends it good ',
#  'great',
#  'nice',
#  'overall great app ',
#  'excellent',
#  'very professional',
#  'great',
#  'app is good but doesn send notifications when meeting is about to start',
#  'it is very nice and highly usefull app',
#  'ok',
#  'future',
#  'i an unbiased reviewer purchase the zoom biz package it has worked very well and is easy to use ',
#  'good app it',
#  'nice aap for online meeting and training ',
#  'very strong software support very clear video and audio',
#  'perfect free program thanks',
#  'nice app',
#  'good',
#  ...]

# %%
from nltk import tokenize
lines_list = tokenize.sent_tokenize(processed_features)
processed_features.extend(lines_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-5074d4ec0003> in <module>
#       1 from nltk import tokenize
# ----> 2 lines_list = tokenize.sent_tokenize(processed_features)
#       3 processed_features.extend(lines_list)
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     104     """
#     105     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# --> 106     return tokenizer.tokenize(text)
#     107
#     108
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in tokenize(self, text, realign_boundaries)
#    1275         Given a text, returns a list of the sentences in that text.
#    1276         """
# -> 1277         return list(self.sentences_from_text(text, realign_boundaries))
#    1278
#    1279     def debug_decisions(self, text):
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1329         follows the period.
#    1330         """
# -> 1331         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1332
#    1333     def _slices_from_text(self, text):
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in <listcomp>(.0)
#    1329         follows the period.
#    1330         """
# -> 1331         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1332
#    1333     def _slices_from_text(self, text):
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in span_tokenize(self, text, realign_boundaries)
#    1319         if realign_boundaries:
#    1320             slices = self._realign_boundaries(text, slices)
# -> 1321         for sl in slices:
#    1322             yield (sl.start, sl.stop)
#    1323
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _realign_boundaries(self, text, slices)
#    1360         """
#    1361         realign = 0
# -> 1362         for sl1, sl2 in _pair_iter(slices):
#    1363             sl1 = slice(sl1.start + realign, sl1.stop)
#    1364             if not sl2:
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _pair_iter(it)
#     316     it = iter(it)
#     317     try:
# --> 318         prev = next(it)
#     319     except StopIteration:
#     320         return
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _slices_from_text(self, text)
#    1333     def _slices_from_text(self, text):
#    1334         last_break = 0
# -> 1335         for match in self._lang_vars.period_context_re().finditer(text):
#    1336             context = match.group() + match.group('after_tok')
#    1337             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
